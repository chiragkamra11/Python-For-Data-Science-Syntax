# %% [markdown]
# # 1. Intro to Seaborn

# %%
'''Seaborn scatterplo'''
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Change this scatter plot to have percent literate on the y-axis
sns.scatterplot(x=gdp, y=percent_literate)

# Show plot
plt.show()

# %%
'''count-plot'''
# Create count plot with region on the y-axis
sns.countplot(y=region)
'''x = gives vertical bars... y= gives horizontal bars'''

# %%
'''count-plot with pandas'''

sns.countplot(x="Spiders", data=df)

# %%
'''adding 3rd variable in scatterplot as color'''

sns.scatterplot(x="absences", y="G3", 
                data=student_data, 
                hue="location", hue_order = ["Rural","Urban"])

# %%
'''another way of adding order plus custom color pallette for hue'''

# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "green", "Urban": "blue"}

# Create a count plot of school with location subgroups
sns.countplot(x="school", data=student_data,
              hue="location",
              palette=palette_colors)

# %% [markdown]
# # 2. Visualizing Two Quantitative Variables

# %%
'''using relplot instead of scatterplot for subplots'''
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter", 
            row="study_time")

# Show plot
plt.show()

# %%
'''2 factor subplots'''

sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row = "famsup",
            row_order = ["yes","no"])

# %%
'''size of plot points'''

# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders", hue= "cylinders")

# %%
'''style of plot points'''
# Create a scatter plot of acceleration vs. mpg
sns.relplot(x="acceleration", y="mpg", 
            data=mpg, kind="scatter", 
            style="origin", hue="origin")

'''style generally works for categorical vars'''

# %%
'''Line Plots'''

# Create line plot
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line")

#lineplots by default give a confidence interval since we're plotting year vs mpg, year in the plot gives you 
#mean mpg for that year. To chagne default from confidence interval to st. dev, we use ci.

sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line",ci = "sd")

'''Use the dashes parameter to use solid lines for
all countries, while still allowing for different marker styles for each line.'''

'''ci = False for no confidence intervals'''

sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin", dashes = False, markers = True)

'''markers are for dots'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Visualizing Categorical and Quantitative Variable
